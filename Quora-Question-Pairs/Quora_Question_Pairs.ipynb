ive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1639550853&Signature=ntKKQK7fTXxjAIp5opeEpKWiaujyjsm2%2F3G9KMsJl8H+IMmzQtEvtjBwlxNy4gQTzBSy%2FWm1CV0t0sD%2FwMeQIrOT7rUnJV0ZpDKDfFeMU3LYm0X8rGQh5B+KAbG8Dh2.3’ saved [323899260/323899260]

# %%
zip_ref = zipfile.ZipFile("archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1639550853&Signature=ntKKQK7fTXxjAIp5opeEpKWiaujyjsm2%2F3G9KMsJl8H+IMmzQtEvtjBwlxNy4gQTzBSy%2FWm1CV0t0sD%2FwMeQIrOT7rUnJV0ZpDKDfFeMU3LYm0X8rGQh5B+KAbG8Dh2", "r")
zip_ref.extractall()
zip_ref.close()

# %%
zip_ref = zipfile.ZipFile("test.csv.zip", "r")
zip_ref.extractall()
zip_ref.close()
zip_ref = zipfile.ZipFile("train.csv.zip", "r")
zip_ref.extractall()
zip_ref.close()

# %%
import pandas as pd

train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # EDA

# %%
pd.set_option("display.max_colwidth", -1)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
print(train_data.shape , test_data.shape)
train_data.head()
# Out:
# (404290, 6) (3563475, 3)
#    id  qid1  qid2  \
# 0  0   1     2
# 1  1   3     4
# 2  2   5     6
# 3  3   7     8
# 4  4   9     10
#
#                                                                       question1  \
# 0  What is the step by step guide to invest in share market in india?
# 1  What is the story of Kohinoor (Koh-i-Noor) Diamond?
# 2  How can I increase the speed of my internet connection while using a VPN?
# 3  Why am I mentally very lonely? How can I solve it?
# 4  Which one dissolve in water quikly sugar, salt, methane and carbon di oxide?
#
#                                                                                   question2  \
# 0  What is the step by step guide to invest in share market?
# 1  What would happen if the Indian government stole the Kohinoor (Koh-i-Noor) diamond back?
# 2  How can Internet speed be increased by hacking through DNS?
# 3  Find the remainder when [math]23^{24}[/math] is divided by 24,23?
# 4  Which fish would survive in salt water?
#
#    is_duplicate
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %%
test_data.head()
# Out:
#   test_id                                                           question1  \
# 0  0       How does the Surface Pro himself 4 compare with iPad Pro?
# 1  1       Should I have a hair transplant at age 24? How much would it cost?
# 2  2       What but is the best way to send money from China to the US?
# 3  3       Which food not emulsifiers?
# 4  4       How "aberystwyth" start reading?
#
#                                                               question2
# 0  Why did Microsoft choose core m3 and not core i3 home Surface Pro 4?
# 1  How much cost does hair transplant require?
# 2  What you send money to China?
# 3  What foods fibre?
# 4  How their can I start reading?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid")
ax = sns.countplot(x="is_duplicate", data =train_data)
plt.show()

# %%
train_qs = pd.Series(train_data['question1'].tolist() + train_data['question2'].tolist()).astype(str)
test_qs = pd.Series(train_data['question1'].tolist() + train_data['question2'].tolist()).astype(str)

dist_train = train_qs.apply(len)
dist_test = test_qs.apply(len)
plt.figure(figsize=(15, 10))
plt.hist(dist_train, bins=200, range=[0, 200],color='b', density=False,stacked=False, label='train')
plt.hist(dist_test, bins=200, range=[0, 200],color='r', density=False,stacked=False, alpha=0.5, label='test')
plt.title('Normalised histogram of character count in questions', fontsize=15)
plt.legend()
plt.xlabel('Number of characters', fontsize=15)
plt.ylabel('Probability', fontsize=15)

print('mean-train {:.2f} std-train {:.2f} mean-test {:.2f} std-test {:.2f} max-train {:.2f} max-test {:.2f}'.format(dist_train.mean(), 
                          dist_train.std(), dist_test.mean(), dist_test.std(), dist_train.max(), dist_test.max()))
# Out:
# mean-train 59.82 std-train 31.96 mean-test 59.82 std-test 31.96 max-train 1169.00 max-test 1169.00

# %%
dist_train = train_qs.apply(lambda x: len(x.split(' ')))
dist_test = test_qs.apply(lambda x: len(x.split(' ')))

plt.figure(figsize=(15, 10))
plt.hist(dist_train, bins=50, range=[0, 50], color='red',  label='train')
plt.hist(dist_test, bins=50, range=[0, 50], color='palegreen', alpha=0.5, label='test')
plt.title('Normalised histogram of word count in questions', fontsize=15)
plt.legend()
plt.xlabel('Number of words', fontsize=15)
plt.ylabel('Probability', fontsize=15)
# Out:
# Text(0, 0.5, 'Probability')

# %%
from wordcloud import WordCloud
cloud = WordCloud(width=1440, height=1080).generate(" ".join(train_data['question1'].astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 1439.5, 1079.5, -0.5)

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Testing nltk 
stopWords = nltk.corpus.stopwords.words('english')
len(stopWords)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 179

# %%
import nltk

def RemoveStopWords(text):
  stopWords = nltk.corpus.stopwords.words('english')
  noStopWords = [word for word in text if word not in stopWords]
  return noStopWords

# %%
from wordcloud import WordCloud
cloud = WordCloud(width=1440, height=1080).generate(" ".join(train_data['question2'].astype(str)))
plt.figure(figsize=(20, 15))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 1439.5, 1079.5, -0.5)

# %%
DeleteWords = ('india','best','difference','way','will','good','use','one','donald','trump')

# %%
train_data[train_data.duplicated(subset=['question1','question2'])]
# Out:
# Empty DataFrame
# Columns: [id, qid1, qid2, question1, question2, is_duplicate]
# Index: []

# %%
train_data['question1'].head()
# Out:
# 0    What is the step by step guide to invest in share market in india?
# 1    What is the story of Kohinoor (Koh-i-Noor) Diamond?
# 2    How can I increase the speed of my internet connection while using a VPN?
# 3    Why am I mentally very lonely? How can I solve it?
# 4    Which one dissolve in water quikly sugar, salt, methane and carbon di oxide?
# Name: question1, dtype: object

# %% [markdown]
# No duplicated pair questions

# %%
train_data.isna().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
rowsWithNan = [index for index, row in train_data.iterrows() if row.isnull().any()]

# %%
for i in rowsWithNan:
  print(train_data.iloc[[i]])
# Out:
#             id    qid1    qid2                       question1 question2  \
# 105780  105780  174363  174364  How can I develop android app?  NaN
#
#         is_duplicate
# 105780  0
#             id    qid1    qid2                         question1 question2  \
# 201841  201841  303951  174364  How can I create an Android app?  NaN
#
#         is_duplicate
# 201841  0
#             id    qid1    qid2 question1  \
# 363362  363362  493340  493341  NaN
#
#                                                                                                                           question2  \
# 363362  My Chinese name is Haichao Yu. What English name is most suitable for me considering the pronounciation of my Chinese name?
#
#         is_duplicate
# 363362  0

# %% [markdown]
# We will remove these rows in cleaning phase

# %% [markdown]
# # Data Cleaning

# %%
abbrDict={
    "what's":"what is",
    "what're":"what are",
    "who's":"who is",
    "who're":"who are",
    "where's":"where is",
    "where're":"where are",
    "when's":"when is",
    "when're":"when are",
    "how's":"how is",
    "how're":"how are",

    "i'm":"i am",
    "we're":"we are",
    "you're":"you are",
    "they're":"they are",
    "it's":"it is",
    "he's":"he is",
    "she's":"she is",
    "that's":"that is",
    "there's":"there is",
    "there're":"there are",

    "i've":"i have",
    "we've":"we have",
    "you've":"you have",
    "they've":"they have",
    "who've":"who have",
    "would've":"would have",
    "not've":"not have",

    "i'll":"i will",
    "we'll":"we will",
    "you'll":"you will",
    "he'll":"he will",
    "she'll":"she will",
    "it'll":"it will",
    "they'll":"they will",

    "isn't":"is not",
    "wasn't":"was not",
    "aren't":"are not",
    "weren't":"were not",
    "can't":"can not",
    "couldn't":"could not",
    "don't":"do not",
    "didn't":"did not",
    "shouldn't":"should not",
    "wouldn't":"would not",
    "doesn't":"does not",
    "haven't":"have not",
    "hasn't":"has not",
    "hadn't":"had not",
    "won't":"will not",


    "hong kong":"hong-kong",



    " %":"%",
    "%":"%",
    " -":" ",
    " - ":" ",
    "- ": " ",


    'india': "",
    'best': "" ,
    'difference': "",
    'way': "",
    'good': "",
    'use': "",
    'one': "",
    'donald': "",
    'trump': ""


}

# %%
punct = ['/','[',']','"',"'",'{','}',"\\" ]
exceptions =  ['-','.',"+","=","*",":"]

# %%
import string 
# Create a function for removing punctuation
def RemovePunctaution(text):
    repacePunctaution = []
    for words in text:
      if words in punct:
        repacePunctaution.append(' ')
      else:
        repacePunctaution.append(words)
    noPunctaution = [words for words in ''.join(repacePunctaution) if ( words not in string.punctuation or words in exceptions)]
    return ' '.join(''.join(noPunctaution).split())

# %%
import string 
import re
# Create a function for removing punctuation
def ReplacePunctaution(text):
    words = text.split()
    noPunctaution = []
    for word in words:
       if word in abbrDict.keys():
            noPunctaution.append(abbrDict[word])
       else :
            noPunctaution.append(word)
    return ' '.join(noPunctaution)

# %%
# Make a fucntion for convert Upper letter to lower letter and number remover
def UpperToLower(text):
    noUpperCase = [words.lower() for words in text]
    return ''.join(noUpperCase)

# %%
# TODO : use stopwords after building model and  remove number  adn lemmitize
def Pipline(data):
  print(f'shpae before pipline {data.shape}')
  data.drop(data.index[rowsWithNan])
  for question in ['question1','question2']:
    data[question] = data[question].astype(str)
    data[f'{question}-after-cleaning'] = data[question].apply(lambda x : UpperToLower(x))
    data[f'{question}-after-cleaning'] = data[f'{question}-after-cleaning'].apply(lambda x : ReplacePunctaution(x))
    data[f'{question}-after-cleaning'] = data[f'{question}-after-cleaning'].apply(lambda x : RemovePunctaution(x))
  print(f'shpae after pipline {data.shape}')

# %%
Pipline(train_data)
# Out:
# shpae before pipline (404290, 6)
# shpae after pipline (404290, 8)

# %%
train_data.sample(n=10)
# Out:
#             id    qid1    qid2  \
# 28350   28350   52581   52582
# 278141  278141  102484  20305
# 370513  370513  501081  501082
# 120786  120786  195863  195864
# 288324  288324  409260  409261
# 380193  380193  65141   27075
# 97827   97827   37706   162696
# 261472  261472  329226  377624
# 299226  299226  421838  421839
# 229013  229013  338227  338228
#
#                                                                          question1  \
# 28350   Which is the best Indian short film?
# 278141  How do I recover deleted messages on my dm on Instagram?
# 370513  Should psychiatrists be trusted?
# 120786  What is the meaning behind Jamaica's flag?
# 288324  Is Google Cardboard any good for VR porn-watching?
# 380193  How do I make cake?
# 97827   What is the best compliment you ever got from anyone?
# 261472  Is repairing my MacBook Air's logic board worth the cost?
# 299226  How can I get better at writing book reviews ? whats the best way to write
# 229013  Does the military really have defence scenarios for fighting zombies?
#
#                                                                                                                                                      question2  \
# 28350   What are some must-watch Indian short movies/films?
# 278141  How can I get deleted messages from Instagram?
# 370513  How can I trust a psychiatrist?
# 120786  What is the story behind your country's flag?
# 288324  Will I be able to watch movies on Google Cardboard?
# 380193  How does one make a cake?
# 97827   What is the best compliment you have ever received?
# 261472  Is the MacBook Air worth the cost? Why or why not?
# 299226  How can I get better at writing book reviews?
# 229013  What happened to the French military? In the 1800s, it could fight the whole of Europe. In the 1950s, France couldn't fight Vietnam even with US help.
#
#         is_duplicate  \
# 28350   1
# 278141  1
# 370513  0
# 120786  0
# 288324  0
# 380193  1
# 97827   1
# 261472  0
# 299226  1
# 229013  0
#
#                                                     question1-after-cleaning  \
# 28350   which is the indian short film
# 278141  how do i recover deleted messages on my dm on instagram
# 370513  should psychiatrists be trusted
# 120786  what is the meaning behind jamaica s flag
# 288324  is google cardboard any for vr porn-watching
# 380193  how do i make cake
# 97827   what is the compliment you ever got from anyone
# 261472  is repairing my macbook air s logic board worth the cost
# 299226  how can i get better at writing book reviews whats the to write
# 229013  does the military really have defence scenarios for fighting zombies
#
#                                                                                                                                     question2-after-cleaning
# 28350   what are some must-watch indian short movies films
# 278141  how can i get deleted messages from instagram
# 370513  how can i trust a psychiatrist
# 120786  what is the story behind your country s flag
# 288324  i be able to watch movies on google cardboard
# 380193  how does make a cake
# 97827   what is the compliment you have ever received
# 261472  is the macbook air worth the cost why or why not
# 299226  how can i get better at writing book reviews
# 229013  what happened to the french military in the 1800s it could fight the whole of europe. in the 1950s france could not fight vietnam even with us help.

# %% [markdown]
# # TODO
# * Search for more EDA X
# * Delete same word for question 1 and question 2 X
# * Finding full duplicated questions! X
# * #####
# * Use a pipline for data cleaning X
# * Featue Extracting
# * #####
# * Word2Vec
# * Sent2Vec
# * ####
# * Modeling?
